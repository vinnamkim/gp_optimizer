# %%
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("C:\\Users\\Samsung\\MNIST", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-6-acc55e33c4e1>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\Samsung\Anaconda2\envs\tf\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\Samsung\Anaconda2\envs\tf\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
plot_data = {}

# %%
# Parameters
learning_rate = 0.1
training_epochs = 40
batch_size = 100
display_step = 1

# tf Graph Input
x = tf.placeholder(tf.float32, [None, 784]) # mnist data image of shape 28*28=784
y = tf.placeholder(tf.float32, [None, 10]) # 0-9 digits recognition => 10 classes

# Set model weights
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))

# Construct model
pred = tf.nn.softmax(tf.matmul(x, W) + b) # Softmax

# Minimize error using cross entropy
cost = tf.reduce_mean(-tf.reduce_sum(y*tf.log(pred), reduction_indices=1))
# Gradient Descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

avg_costs = []

# Start training
with tf.Session() as sess:
    # Run the initializer
    sess.run(init)

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c = sess.run([optimizer, cost], feed_dict={x: batch_xs,
                                                          y: batch_ys})
            # Compute average loss
            avg_cost += c / total_batch
        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost))
        
        avg_costs.append(avg_cost)

    print("Optimization Finished!")

    # Test model
    correct_prediction = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y: mnist.test.labels}))
# Out:
# Epoch: 0001 cost= 0.549552597
# Epoch: 0002 cost= 0.365659649
# Epoch: 0003 cost= 0.336629051
# Epoch: 0004 cost= 0.321285778
# Epoch: 0005 cost= 0.311245082
# Epoch: 0006 cost= 0.304052414
# Epoch: 0007 cost= 0.298589053
# Epoch: 0008 cost= 0.294387549
# Epoch: 0009 cost= 0.290750716
# Epoch: 0010 cost= 0.287643662
# Epoch: 0011 cost= 0.284741480
# Epoch: 0012 cost= 0.282688982
# Epoch: 0013 cost= 0.280704046
# Epoch: 0014 cost= 0.278738015
# Epoch: 0015 cost= 0.277135055
# Epoch: 0016 cost= 0.275611612
# Epoch: 0017 cost= 0.274150288
# Epoch: 0018 cost= 0.272856678
# Epoch: 0019 cost= 0.271608373
# Epoch: 0020 cost= 0.270586427
# Epoch: 0021 cost= 0.269620159
# Epoch: 0022 cost= 0.268894523
# Epoch: 0023 cost= 0.267845975
# Epoch: 0024 cost= 0.266907201
# Epoch: 0025 cost= 0.266017051
# Epoch: 0026 cost= 0.265405160
# Epoch: 0027 cost= 0.264560152
# Epoch: 0028 cost= 0.263853056
# Epoch: 0029 cost= 0.263313201
# Epoch: 0030 cost= 0.262631801
# Epoch: 0031 cost= 0.261992964
# ...

# %%
plot_data['Grad'] = avg_costs

# %%
# Parameters
learning_rate = 0.01
training_epochs = 200
batch_size = 100
display_step = 1

# tf Graph Input
x = tf.placeholder(tf.float32, [None, 784]) # mnist data image of shape 28*28=784
y = tf.placeholder(tf.float32, [None, 10]) # 0-9 digits recognition => 10 classes

# Set model weights
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))

# Construct model
pred = tf.nn.softmax(tf.matmul(x, W) + b) # Softmax

# Minimize error using cross entropy
cost = tf.reduce_mean(-tf.reduce_sum(y*tf.log(pred), reduction_indices=1))
# Gradient Descent
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

avg_costs = []

# Start training
with tf.Session() as sess:
    # Run the initializer
    sess.run(init)

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c = sess.run([optimizer, cost], feed_dict={x: batch_xs,
                                                          y: batch_ys})
            # Compute average loss
            avg_cost += c / total_batch
        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost))
        
        avg_costs.append(avg_cost)

    print("Optimization Finished!")

    # Test model
    correct_prediction = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y: mnist.test.labels}))
# Out:
# Epoch: 0001 cost= 0.636592330
# Epoch: 0002 cost= 0.353107407
# Epoch: 0003 cost= 0.314735649
# Epoch: 0004 cost= 0.296432470
# Epoch: 0005 cost= 0.285267771
# Epoch: 0006 cost= 0.277777101
# Epoch: 0007 cost= 0.272280972
# Epoch: 0008 cost= 0.268052022
# Epoch: 0009 cost= 0.264304108
# Epoch: 0010 cost= 0.261323639
# Epoch: 0011 cost= 0.258810087
# Epoch: 0012 cost= 0.256991199
# Epoch: 0013 cost= 0.254587459
# Epoch: 0014 cost= 0.253035784
# Epoch: 0015 cost= 0.251365321
# Epoch: 0016 cost= 0.250203459
# Epoch: 0017 cost= 0.248689432
# Epoch: 0018 cost= 0.247449213
# Epoch: 0019 cost= 0.246504861
# Epoch: 0020 cost= 0.245351998
# Epoch: 0021 cost= 0.244467272
# Epoch: 0022 cost= 0.243373857
# Epoch: 0023 cost= 0.242599574
# Epoch: 0024 cost= 0.241918571
# Epoch: 0025 cost= 0.241402977
# Epoch: 0026 cost= 0.240510235
# Epoch: 0027 cost= 0.239871627
# Epoch: 0028 cost= 0.239341853
# Epoch: 0029 cost= 0.238917786
# Epoch: 0030 cost= 0.238100650
# Epoch: 0031 cost= 0.237867372
# ...

# %%
plot_data['adam'] = avg_costs

# %%
# Parameters
learning_rate = 0.1
training_epochs = 40
batch_size = 100
display_step = 1

# tf Graph Input
x = tf.placeholder(tf.float32, [None, 784]) # mnist data image of shape 28*28=784
y = tf.placeholder(tf.float32, [None, 10]) # 0-9 digits recognition => 10 classes

# Set model weights
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))

# Construct model
pred = tf.nn.softmax(tf.matmul(x, W) + b) # Softmax

# Minimize error using cross entropy
cost = tf.reduce_mean(-tf.reduce_sum(y*tf.log(pred), reduction_indices=1))
# Gradient Descent
optimizer = tf.train.AdagradOptimizer(learning_rate).minimize(cost)

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

avg_costs = []

# Start training
with tf.Session() as sess:
    # Run the initializer
    sess.run(init)

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c = sess.run([optimizer, cost], feed_dict={x: batch_xs,
                                                          y: batch_ys})
            # Compute average loss
            avg_cost += c / total_batch
        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost))
        
        avg_costs.append(avg_cost)

    print("Optimization Finished!")

    # Test model
    correct_prediction = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y: mnist.test.labels}))
# Out:
# Epoch: 0001 cost= 0.426256183
# Epoch: 0002 cost= 0.319802316
# Epoch: 0003 cost= 0.301166941
# Epoch: 0004 cost= 0.291510767
# Epoch: 0005 cost= 0.284865858
# Epoch: 0006 cost= 0.280368006
# Epoch: 0007 cost= 0.276164707
# Epoch: 0008 cost= 0.273133061
# Epoch: 0009 cost= 0.270534168
# Epoch: 0010 cost= 0.268304566
# Epoch: 0011 cost= 0.266467248
# Epoch: 0012 cost= 0.264589767
# Epoch: 0013 cost= 0.263135596
# Epoch: 0014 cost= 0.261741377
# Epoch: 0015 cost= 0.260231152
# Epoch: 0016 cost= 0.259234204
# Epoch: 0017 cost= 0.258164149
# Epoch: 0018 cost= 0.257125417
# Epoch: 0019 cost= 0.256244996
# Epoch: 0020 cost= 0.255252525
# Epoch: 0021 cost= 0.254600436
# Epoch: 0022 cost= 0.253245583
# Epoch: 0023 cost= 0.253164758
# Epoch: 0024 cost= 0.252452998
# Epoch: 0025 cost= 0.251639838
# Epoch: 0026 cost= 0.251065256
# Epoch: 0027 cost= 0.250545656
# Epoch: 0028 cost= 0.250045651
# Epoch: 0029 cost= 0.249398440
# Epoch: 0030 cost= 0.248818961
# Epoch: 0031 cost= 0.248471472
# ...

# %%
plot_data['AdaGrad'] = avg_costs

# %%
tf.reset_default_graph()
with tf.variable_scope("scope1", reuse=False):
    a1 = tf.get_variable("a", 1)
with tf.variable_scope("scope2", reuse=False):
    a2 = tf.get_variable("a", 1)

# %%
def get_logit_reg_graph():
    x = tf.placeholder(tf.float32, [None, 784]) # mnist data image of shape 28*28=784
    y = tf.placeholder(tf.float32, [None, 10]) # 0-9 digits recognition => 10 classes

    # Set model weights
    W = tf.Variable(tf.zeros([784, 10]))
    b = tf.Variable(tf.zeros([10]))

    # Construct model
    pred = tf.nn.softmax(tf.matmul(x, W) + b) # Softmax

    # Minimize error using cross entropy
    cost = tf.reduce_mean(-tf.reduce_sum(y*tf.log(pred), reduction_indices=1))

    # Construct model
    pred = tf.nn.softmax(tf.matmul(x, W) + b) # Softmax
    
    return x, y, pred, cost

# %%
def get_optimizer(gp_dims, gp_stddev, gp_bias, grads_and_vars):
    grad_num = 0

    for grad, var in grads_and_vars:
        if grad is None:
            continue
            
        grad_num += tf.reshape(grad, [-1]).shape[0].value

    # Set optimizer weights
    A = tf.Variable(
        initial_value=tf.abs(tf.random.normal(
            shape=[grad_num, gp_dims],
            mean=0.0,
            stddev=gp_stddev,
            dtype=tf.dtypes.float32,
            seed=10,
        )),
        trainable=False
    )
    z = tf.placeholder(tf.float32, [gp_dims, 1])
    h = tf.squeeze(tf.matmul(A, z)) + gp_bias
    
    grad_num = 0
    new_grads_and_vars = []
    tmp_vars = []
    for grad, var in grads_and_vars:
        if grad is None:
            continue
            
        this_grad_num = tf.reshape(grad, [-1]).shape[0].value
        new_grads_and_vars.append(
            (grad * tf.reshape(h[grad_num:grad_num + this_grad_num], grad.shape), var)
        )
        grad_num += this_grad_num
        
        tmp_vars.append(tf.Variable(tf.zeros(var.shape)))
    
    optimizer = gradients_descent.apply_gradients(new_grads_and_vars)
    
    save_vars = []
    restore_vars = []
    print_vars = []
    
    for grad_and_var, tmp_var in zip(grads_and_vars, tmp_vars):
        grad, var = grad_and_var
        
        save_vars.append(tf.assign(tmp_var, var))
        restore_vars.append(tf.assign(var, tmp_var))
        print_vars.append(var)
    
    return z, optimizer, save_vars, restore_vars, print_vars

# %%
# Parameters
learning_rate = 1.0
training_epochs = 40
batch_size = 100
display_step = 1

tf.reset_default_graph()

x, y, pred, cost = get_logit_reg_graph()

# Gradient Descent
gradients_descent = tf.train.GradientDescentOptimizer(learning_rate=1.0)
grads_and_vars = gradients_descent.compute_gradients(cost)

z, optimizer, save_vars, restore_vars, print_vars = get_optimizer(
    gp_dims=4, gp_stddev=0.1, gp_bias=0.1, grads_and_vars=grads_and_vars)

# %%
import numpy as np

# %%
# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()
init_z = np.ones([4,1]) * 0.1

# Start training
with tf.Session() as sess:
    # Run the initializer
    sess.run(init)
    
    for i in range(5):
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        sess.run(save_vars)
        _ = sess.run(optimizer, feed_dict={x: batch_xs,
                                                      y: batch_ys,
                                                      z: init_z})
        c = sess.run(cost, feed_dict={x: batch_xs,
                                                      y: batch_ys,
                                                      z: init_z})
        print(c)
        sess.run(restore_vars)
        _ = sess.run(optimizer, feed_dict={x: batch_xs,
                                                      y: batch_ys,
                                                      z: init_z+0.1})
        c = sess.run(cost, feed_dict={x: batch_xs,
                                                      y: batch_ys,
                                                      z: init_z})
        print(c)
        sess.run(restore_vars)
        _, c = sess.run([optimizer, cost], feed_dict={x: batch_xs,
                                                      y: batch_ys,
                                                      z: init_z})
# Out:
# 2.060303
# 2.0098722
# 1.9853051
# 1.9439812
# 1.8960642
# 1.8568367
# 1.7135117
# 1.6662927
# 1.690635
# 1.6544747

# %%
# Parameters
learning_rate = 1.0
training_epochs = 40
batch_size = 100
display_step = 1

tf.reset_default_graph()

x, y, pred, cost = get_logit_reg_graph()
z, optimizer, save_vars, restore_vars = get_optimizer(
    gp_dims=4, gp_stddev=0.1, gp_bias=0.1, cost=cost)

grad_num = 0
new_grads_and_vars = []
for grad, var in grads_and_vars:
    this_grad_num = tf.reshape(grad, [-1]).shape[0].value
    new_grads_and_vars.append(
        (grad * tf.reshape(h[grad_num:grad_num + this_grad_num], grad.shape), var)
    )

optimizer = gradients_descent.apply_gradients(new_grads_and_vars)

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

avg_costs = []

# Start training
with tf.Session() as sess:
    # Run the initializer
    sess.run(init)

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c = sess.run([optimizer, cost], feed_dict={x: batch_xs,
                                                          y: batch_ys})
            # Compute average loss
            avg_cost += c / total_batch
        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost))
        
        avg_costs.append(avg_cost)

    print("Optimization Finished!")

    # Test model
    correct_prediction = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy:", accuracy.eval({x: mnist.test.images, y: mnist.test.labels}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-e20faa32f5fc> in <module>
#       7 tf.reset_default_graph()
#       8
# ----> 9 x, y, pred, cost = get_logit_reg_graph()
#      10 z, optimizer, save_vars, restore_vars = get_optimizer(
#      11     gp_dims=4, gp_stddev=0.1, gp_bias=0.1, cost=cost)
#
# NameError: name 'get_logit_reg_graph' is not defined

# %%
plot_data['Fixed'] = avg_costs

# %%
df = pd.DataFrame(plot_data)
df.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-8bdf76817775> in <module>
# ----> 1 df = pd.DataFrame(plot_data)
#       2 df.plot()
#
# C:\Users\Samsung\Anaconda2\envs\tf\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# C:\Users\Samsung\Anaconda2\envs\tf\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
# ...
